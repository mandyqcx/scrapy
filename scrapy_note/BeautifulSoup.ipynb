# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://slide.news.sina.com.cn/w/slide_1_2841_348402.html')
res.encoding=res.apparent_encoding
print(res.text)
soup=BeautifulSoup(res.text,'html.parser')
# Out:
# <!doctype html>
# <!-- LLTJ_MT:name ="" -->
# <html lang="en">
# <head>
#     <meta charset="gb2312">
#     <title>一艘货船掉落270余个集装箱  海滩上如大型“跳蚤市场”_高清图集_新浪网</title>
#     <meta name="keywords" content="高清图片,荷兰,跳蚤市场,货船,集装箱" />
#     <meta name="tags" content="高清图片,荷兰,跳蚤市场,货船,集装箱" />
#     <meta name="description" content="一艘货船掉落270余个集装箱  海滩上如大型“跳蚤市场”,当地时间2019年1月5日，荷兰劳沃苏格，集装箱船“佐伊号”(MSC Zoe)因遭遇恶劣天气，导致270多个集装箱坠入海洋，大量塑料玩具、鞋子…" />
#     <meta itemprop="name" content="一艘货船掉落270余个集装箱  海滩上如大型“跳蚤市场”" />
#     <meta itemprop="image" content="http://n.sinaimg.cn/news/1_img/vcg/72f96829/53/w1024h629/20190106/KFqi-hrfcctm9607044.jpg" />
#     <meta name="Editor" content="wenyi5" />
#     <meta name="stencil" content="PGLS004271" />    <meta name="sinaads_keywords" content="1,2841" />
#                 <meta name="sudameta" content="allCIDs:200856,257,51895,51923,56262,258,38790" >
# 　　<meta property="article:published_time" content="2019-01-06T07:41:34+08:00"/>
# ...

# %%
soup.select('.main-title')[0].text
# Out:
# '全国铁路31日预计发送旅客915万人次 高铁游受捧'

# %%
soup.select('.date-source')
# Out:
# [<div class="date-source" data-sudaclick="share_1-0">
#  <span class="date">2018年12月31日 15:26</span>
#  <a class="source" data-sudaclick="content_media_p" href="https://www.thepaper.cn/newsDetail_forward_2799781" rel="nofollow" target="_blank">澎湃新闻</a> </div>]

# %%
soup.select('.content')
# Out:
# []
